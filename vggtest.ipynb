# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import cPickle as pickle
# %matplotlib inline

from lasagnekit.misc.draw_net import draw_to_notebook, draw_to_file
from lasagnekit.misc.plot_weights import grid_plot
from lasagnekit.misc.dream import build_dreamer
from lasagnekit.easy import LightweightModel, BatchOptimizer

from lasagne import layers, updates

from IPython.display import SVG

import theano
import theano.tensor as T

from skimage.io import imread
from skimage.transform import resize

from lasagnekit.easy import get_stat

import matplotlib.pyplot as plt

from scipy.ndimage import gaussian_filter
from lasagne.layers import InputLayer, DenseLayer, NonlinearityLayer
from lasagne.layers import Conv2DLayer as ConvLayer
from lasagne.layers import Pool2DLayer as PoolLayer
from lasagne.nonlinearities import softmax
from vgg19 import build_model
# Note: tweaked to use average pooling instead of maxpooling
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.
# Using gpu device 0: Tesla K20m (CNMeM is disabled)

# %%
# !nvidia-smi
# Out:
# Wed Sep  9 10:27:11 2015
# +------------------------------------------------------+
# | NVIDIA-SMI 5.319.37   Driver Version: 319.37         |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K20m          Off  | 0000:05:00.0     Off |                    0 |
# | N/A   37C    P0    46W / 225W |       91MB /  4799MB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla K20m          Off  | 0000:42:00.0     Off |                    0 |
# | N/A   34C    P8    48W / 225W |       11MB /  4799MB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Compute processes:                                               GPU Memory |
# |  GPU       PID  Process name                                     Usage      |
# |=============================================================================|
# |    0     31310  /home/gridcl/mehdicherti/anaconda/bin/python          76MB  |
# +-----------------------------------------------------------------------------+

# %%
# build VGG net and load weights
net = build_model()
model_data = pickle.load(open('vgg19.pkl'))
values = model_data['param values']
layers.set_all_param_values(net['prob'], values)

# %%
print(net.keys())
# Out:
# ['input', 'conv1_1', 'conv1_2', 'pool1', 'conv2_1', 'conv2_2', 'pool2', 'conv3_1', 'conv3_2', 'conv3_3', 'conv3_4', 'pool3', 'conv4_1', 'conv4_2', 'conv4_3', 'conv4_4', 'pool4', 'conv5_1', 'conv5_2', 'conv5_3', 'conv5_4', 'pool5', 'fc6', 'fc7', 'fc8', 'prob']

# %%
model = net
classes = np.array(model_data["synset words"])
mean_value = model_data["mean value"]

# %%
draw_to_file(layers.get_all_layers(model['prob']), "vgg.svg")

# %%
SVG("vgg.svg")

# %%
X_batch = theano.tensor.tensor4()
predict = theano.function([X_batch], layers.get_output(model["prob"], X_batch))
pre_predict = theano.function([X_batch], layers.get_output(model["fc8"], X_batch))

# %%
# !wget http://www.dph.am/sky1024px.jpg --output-document=sample.png
# Out:
# --2015-09-10 09:51:33--  http://www.dph.am/sky1024px.jpg
# Resolving www.dph.am... 198.244.107.6
# Connecting to www.dph.am|198.244.107.6|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57024 (56K) [image/jpeg]
# Saving to: “sample.png”
#
# 100%[======================================>] 57,024       107K/s   in 0.5s
#
# 2015-09-10 09:51:34 (107 KB/s) - “sample.png” saved [57024/57024]

# %%
from IPython.display import Image
img = Image("sample.png")

# %%
image = imread("sample.png")

# %%
X = resize(image, (224, 224), preserve_range=True)
a = X
X =  X
X = X.transpose((2, 1, 0))[np.newaxis, :, :, :]
#X = X[::-1, :, :]
X = X - mean_value[np.newaxis, :, np.newaxis, np.newaxis]
X = X.astype(np.float32)

# %%
print(mean_value)
# Out:
# [ 103.939  116.779  123.68 ]

# %%
cl_index = list(reversed(np.argsort(predict(X)[0])))

# %%
print(cl_index[0:5])
# Out:
# [974, 980, 803, 792, 908]

# %%
print(classes[cl_index[0:5]])
# Out:
# ['geyser' 'volcano' 'snowplow, snowplough' 'shovel' 'wing']

# %%
# !nvidia-smi
# Out:
# Tue Sep  8 23:56:36 2015
# +------------------------------------------------------+
# | NVIDIA-SMI 5.319.37   Driver Version: 319.37         |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K20m          Off  | 0000:05:00.0     Off |                    0 |
# | N/A   38C    P0    50W / 225W |      825MB /  4799MB |     36%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla K20m          Off  | 0000:42:00.0     Off |                    0 |
# | N/A   34C    P8    26W / 225W |       11MB /  4799MB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Compute processes:                                               GPU Memory |
# |  GPU       PID  Process name                                     Usage      |
# |=============================================================================|
# |    0     23639  /home/gridcl/mehdicherti/anaconda/bin/python         810MB  |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## dream

# %%
def sigmoid(x):
    return 1./(1. + np.exp(-x))
theta = 0.000
X_gen = X.copy()

X_gen = np.random.uniform(-128, 128, size=X.shape).astype(np.float32)
#X_gen = np.zeros_like(X)

loss_function = lambda i, act: -((act[0, 0]).sum()) #+ (T.abs_(i)).mean()*0.1

class MyBatchOptimizer(BatchOptimizer):
    
    def iter_update(self, epoch, nb_batches, iter_update_batch):
        status = super(MyBatchOptimizer, self).iter_update(epoch, nb_batches, iter_update_batch)
        status["pred"] = (pre_predict((dreamer.inputs.get_value()))[0, 0])
        self.model.inputs.set_value((1 - theta) * self.model.inputs.get_value())
        #self.model.inputs.set_value(
        #    gaussian_filter(self.model.inputs.get_value(), 4) * 0.000001+
        #    self.model.inputs.get_value() * 0.999999
        #)
        
        return status
    
batch_optimizer = MyBatchOptimizer(verbose=1,
                                   max_nb_epochs=1000,
                                   whole_dataset_in_device=False,
                                   optimization_procedure=(updates.sgd, 
                                                          {"learning_rate": .01}))
mv = (mean_value[np.newaxis, :, np.newaxis, np.newaxis].astype(np.float32))
dreamer = build_dreamer(
    LightweightModel([model["input"]], 
                     [model["conv1_1"]]),
    X_gen,
    loss_function=loss_function,
    input_type=theano.tensor.tensor4,
    batch_optimizer=batch_optimizer,
    parse_grads=lambda grads:[grad/theano.tensor.abs_(grad).mean() for grad in grads]
)

# %%
dreamer.fit(X=X_gen)
# Out:
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#       0           0  -2.25627e+06  0.953732
#   epoch    loss_std    loss_train     pred
# -------  ----------  ------------  -------
#       1           0  -2.25733e+06  0.95357
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#       2           0  -2.25838e+06  0.953379
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#       3           0  -2.25944e+06  0.953236
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#       4           0   -2.2605e+06  0.953087
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#       5           0  -2.26156e+06  0.952931
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#       6           0  -2.26262e+06  0.952727
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#       7           0  -2.26368e+06  0.952506
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#       8           0  -2.26474e+06  0.952257
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#       9           0   -2.2658e+06  0.952004
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#      10           0  -2.26686e+06  0.951742
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     202           0  -2.47081e+06  0.880877
#   epoch    loss_std    loss_train     pred
# -------  ----------  ------------  -------
#     203           0  -2.47188e+06  0.88034
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     204           0  -2.47294e+06  0.879803
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     205           0  -2.47401e+06  0.879284
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     206           0  -2.47508e+06  0.878773
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     207           0  -2.47614e+06  0.878233
#   epoch    loss_std    loss_train    pred
# -------  ----------  ------------  ------
#     208           0  -2.47721e+06  0.8777
#   epoch    loss_std    loss_train    pred
# -------  ----------  ------------  ------
#     209           0  -2.47827e+06  0.8772
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     210           0  -2.47934e+06  0.876709
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     211           0   -2.4804e+06  0.876226
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     212           0  -2.48147e+06  0.875757
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     213           0  -2.48253e+06  0.875287
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     214           0   -2.4836e+06  0.874797
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     215           0  -2.48466e+06  0.874315
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     216           0  -2.48573e+06  0.873825
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     217           0   -2.4868e+06  0.873339
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     218           0  -2.48786e+06  0.872847
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     219           0  -2.48893e+06  0.872335
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     220           0  -2.48999e+06  0.871863
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     221           0  -2.49106e+06  0.871387
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     222           0  -2.49212e+06  0.870918
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     223           0  -2.49319e+06  0.870464
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     224           0  -2.49426e+06  0.870016
#   epoch    loss_std    loss_train     pred
# -------  ----------  ------------  -------
#     225           0  -2.49532e+06  0.86956
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     226           0  -2.49639e+06  0.869077
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     227           0  -2.49745e+06  0.868609
#   epoch    loss_std    loss_train     pred
# -------  ----------  ------------  -------
#     228           0  -2.49852e+06  0.86816
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     229           0  -2.49959e+06  0.867718
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     230           0  -2.50065e+06  0.867279
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     231           0  -2.50172e+06  0.866881
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     232           0  -2.50279e+06  0.866481
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     233           0  -2.50385e+06  0.866068
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     234           0  -2.50492e+06  0.865658
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     235           0  -2.50598e+06  0.865276
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     236           0  -2.50705e+06  0.864848
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     237           0  -2.50812e+06  0.864432
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     238           0  -2.50918e+06  0.863993
#   epoch    loss_std    loss_train     pred
# -------  ----------  ------------  -------
#     239           0  -2.51025e+06  0.86356
#   epoch    loss_std    loss_train     pred
# -------  ----------  ------------  -------
#     240           0  -2.51132e+06  0.86306
#   epoch    loss_std    loss_train     pred
# -------  ----------  ------------  -------
#     241           0  -2.51238e+06  0.86257
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     242           0  -2.51345e+06  0.862048
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     243           0  -2.51452e+06  0.861512
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     244           0  -2.51558e+06  0.860978
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     245           0  -2.51665e+06  0.860435
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     246           0  -2.51771e+06  0.859875
#   epoch    loss_std    loss_train     pred
# -------  ----------  ------------  -------
#     247           0  -2.51878e+06  0.85925
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     248           0  -2.51985e+06  0.858616
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     249           0  -2.52091e+06  0.857972
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     250           0  -2.52198e+06  0.857333
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     251           0  -2.52305e+06  0.856649
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     252           0  -2.52411e+06  0.855942
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     253           0  -2.52518e+06  0.855274
#   epoch    loss_std    loss_train     pred
# -------  ----------  ------------  -------
#     254           0  -2.52625e+06  0.85462
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     255           0  -2.52732e+06  0.853953
#   epoch    loss_std    loss_train     pred
# -------  ----------  ------------  -------
#     256           0  -2.52838e+06  0.85325
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     257           0  -2.52945e+06  0.852555
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     904           0  -3.22502e+06  0.117285
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     905           0  -3.22611e+06  0.115619
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     906           0  -3.22719e+06  0.113966
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     907           0  -3.22827e+06  0.112339
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     908           0  -3.22936e+06  0.110703
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     909           0  -3.23044e+06  0.109075
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     910           0  -3.23152e+06  0.107429
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     911           0   -3.2326e+06  0.105776
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     912           0  -3.23369e+06  0.104143
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     913           0  -3.23477e+06  0.102517
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     914           0  -3.23585e+06  0.100918
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     915           0  -3.23693e+06  0.0993243
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     916           0  -3.23802e+06  0.0977464
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     917           0   -3.2391e+06  0.096172
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     918           0  -3.24018e+06  0.094596
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     919           0  -3.24127e+06  0.0930512
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     920           0  -3.24235e+06  0.0915274
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     921           0  -3.24343e+06  0.0899851
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     922           0  -3.24451e+06  0.0884559
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     923           0   -3.2456e+06  0.0869611
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     924           0  -3.24668e+06  0.0854601
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     925           0  -3.24776e+06  0.0839352
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     926           0  -3.24885e+06  0.0823954
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     927           0  -3.24993e+06  0.0808635
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     928           0  -3.25101e+06  0.0793406
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     929           0  -3.25209e+06  0.0778165
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     930           0  -3.25318e+06  0.0763087
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     931           0  -3.25426e+06  0.074846
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     932           0  -3.25534e+06  0.0733679
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     933           0  -3.25643e+06  0.0718789
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     934           0  -3.25751e+06  0.0703885
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     935           0  -3.25859e+06  0.0689026
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     936           0  -3.25968e+06  0.0673855
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     937           0  -3.26076e+06  0.0658695
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     938           0  -3.26184e+06  0.0643618
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     939           0  -3.26292e+06  0.0628461
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     940           0  -3.26401e+06  0.0613267
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     941           0  -3.26509e+06  0.0598051
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     942           0  -3.26618e+06  0.0582891
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     943           0  -3.26726e+06  0.0567855
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     944           0  -3.26834e+06  0.0552983
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     945           0  -3.26942e+06  0.0538545
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     946           0  -3.27051e+06  0.0523858
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     947           0  -3.27159e+06  0.0508992
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     948           0  -3.27268e+06  0.0494462
#   epoch    loss_std    loss_train      pred
# -------  ----------  ------------  --------
#     949           0  -3.27376e+06  0.047996
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     950           0  -3.27484e+06  0.0465188
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     951           0  -3.27593e+06  0.0450403
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     952           0  -3.27701e+06  0.0435624
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     953           0  -3.27809e+06  0.0420844
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     954           0  -3.27918e+06  0.0406049
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     955           0  -3.28026e+06  0.0391285
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     956           0  -3.28134e+06  0.0376209
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     957           0  -3.28243e+06  0.0360945
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     958           0  -3.28351e+06  0.0345644
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     959           0  -3.28459e+06  0.0330343
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     960           0  -3.28568e+06  0.0315338
#   epoch    loss_std    loss_train     pred
# -------  ----------  ------------  -------
#     961           0  -3.28676e+06  0.03006
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     962           0  -3.28785e+06  0.0286025
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     963           0  -3.28893e+06  0.0271589
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     964           0  -3.29001e+06  0.0257217
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     965           0   -3.2911e+06  0.0242833
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     966           0  -3.29218e+06  0.0228889
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     967           0  -3.29326e+06  0.0214792
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     968           0  -3.29435e+06  0.0200776
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     969           0  -3.29543e+06  0.0186258
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     970           0  -3.29652e+06  0.0171526
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     971           0   -3.2976e+06  0.0156797
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     972           0  -3.29868e+06  0.0141963
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     973           0  -3.29977e+06  0.0126989
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     974           0  -3.30085e+06  0.0111972
#   epoch    loss_std    loss_train        pred
# -------  ----------  ------------  ----------
#     975           0  -3.30193e+06  0.00969593
#   epoch    loss_std    loss_train        pred
# -------  ----------  ------------  ----------
#     976           0  -3.30302e+06  0.00821513
#   epoch    loss_std    loss_train        pred
# -------  ----------  ------------  ----------
#     977           0   -3.3041e+06  0.00677665
#   epoch    loss_std    loss_train        pred
# -------  ----------  ------------  ----------
#     978           0  -3.30519e+06  0.00536349
#   epoch    loss_std    loss_train        pred
# -------  ----------  ------------  ----------
#     979           0  -3.30627e+06  0.00393607
#   epoch    loss_std    loss_train       pred
# -------  ----------  ------------  ---------
#     980           0  -3.30735e+06  0.0024686
#   epoch    loss_std    loss_train         pred
# -------  ----------  ------------  -----------
#     981           0  -3.30844e+06  0.000991508
#   epoch    loss_std    loss_train          pred
# -------  ----------  ------------  ------------
#     982           0  -3.30952e+06  -0.000477418
#   epoch    loss_std    loss_train         pred
# -------  ----------  ------------  -----------
#     983           0   -3.3106e+06  -0.00195538
#   epoch    loss_std    loss_train         pred
# -------  ----------  ------------  -----------
#     984           0  -3.31169e+06  -0.00343235
#   epoch    loss_std    loss_train         pred
# -------  ----------  ------------  -----------
#     985           0  -3.31277e+06  -0.00491109
#   epoch    loss_std    loss_train         pred
# -------  ----------  ------------  -----------
#     986           0  -3.31386e+06  -0.00637263
#   epoch    loss_std    loss_train         pred
# -------  ----------  ------------  -----------
#     987           0  -3.31494e+06  -0.00785325
#   epoch    loss_std    loss_train         pred
# -------  ----------  ------------  -----------
#     988           0  -3.31602e+06  -0.00932907
#   epoch    loss_std    loss_train        pred
# -------  ----------  ------------  ----------
#     989           0  -3.31711e+06  -0.0108038
#   epoch    loss_std    loss_train        pred
# -------  ----------  ------------  ----------
#     990           0  -3.31819e+06  -0.0122752
#   epoch    loss_std    loss_train        pred
# -------  ----------  ------------  ----------
#     991           0  -3.31928e+06  -0.0137602
#   epoch    loss_std    loss_train        pred
# -------  ----------  ------------  ----------
#     992           0  -3.32036e+06  -0.0152174
#   epoch    loss_std    loss_train        pred
# -------  ----------  ------------  ----------
#     993           0  -3.32144e+06  -0.0166304
#   epoch    loss_std    loss_train        pred
# -------  ----------  ------------  ----------
#     994           0  -3.32253e+06  -0.0180149
#   epoch    loss_std    loss_train        pred
# -------  ----------  ------------  ----------
#     995           0  -3.32361e+06  -0.0194113
#   epoch    loss_std    loss_train        pred
# -------  ----------  ------------  ----------
#     996           0   -3.3247e+06  -0.0208002
#   epoch    loss_std    loss_train        pred
# -------  ----------  ------------  ----------
#     997           0  -3.32578e+06  -0.0221616
#   epoch    loss_std    loss_train        pred
# -------  ----------  ------------  ----------
#     998           0  -3.32686e+06  -0.0235081
#   epoch    loss_std    loss_train        pred
# -------  ----------  ------------  ----------
#     999           0  -3.32795e+06  -0.0248494

# %%
pred = get_stat("pred", dreamer.batch_optimizer.stats)
loss = get_stat("loss_train", dreamer.batch_optimizer.stats)
epoch = get_stat("epoch", dreamer.batch_optimizer.stats)
#plt.plot(epoch, pred, label="pred")
plt.plot(epoch, loss, label="loss")
plt.legend()

# %%
X_gen = dreamer.inputs.get_value(borrow=True)
print(X_gen.min(), X_gen.max())
X_gen_ = X_gen
X_gen = X_gen + mean_value[np.newaxis, :, np.newaxis, np.newaxis]
X_gen = X_gen[:, ::-1, :, :]
print(X_gen.min(), X_gen.max())
X_gen = X_gen.transpose((0, 3, 2, 1))
plt.imshow(X_gen[0])
# Out:
# (-152.14328, 153.03038)
# (-43.31675256347657, 273.77445190429688)

# %%
cl_index = list(reversed(np.argsort(predict(X_gen_.astype(np.float32))[0])))

# %%
print(cl_index[0:10])
# Out:
# [611, 539, 794, 741, 775, 735, 721, 750, 411, 599]

# %% [markdown]
# ## manual

# %%
#L = T.sqrt((layers.get_output(model["conv1_1"], X_batch)**2).sum())
L = 0.5*(layers.get_output(model["conv3_2"], X_batch)**2).sum()
get_grad = theano.function([X_batch], theano.grad(L,
                                                  X_batch))
get_loss =  theano.function([X_batch], L)

# %%
mv = (mean_value[np.newaxis, :, np.newaxis, np.newaxis].astype(np.float32))

# %%
alpha = 1

curve = []
grads_mean = []
grads_std = []
X_gen = np.random.uniform(0, 255, size=X.shape).astype(np.float32)
X_gen -= mv
l = None
#X_gen = np.zeros_like(X)
for i in range(1000):
    g = get_grad(X_gen)
    X_gen += (alpha/ (np.abs(g).mean())) * g 
    #X_gen += alpha * g
    #X_gen += np.random.uniform(size=X.shape)
    #X_gen += alpha * (g - 0.001 * 0.5 * X_gen)
    #X_gen = (1 - 0.00001) * X_gen
    prev_l = l
    l = get_loss(X_gen)
    
    #if prev_l is not None and  l <= prev_l:
    #    alpha /= 2
    curve.append(l)
    if i % 10==0:
        print(l)
    grads_mean.append(g.mean())
    grads_std.append(g.std())
# Out:
# 74331553792.0
# 81497391104.0
# 98133532672.0
# 1.2234694656e+11
# 1.532977152e+11
# 1.90779179008e+11
# 2.34724524032e+11
# 2.85172498432e+11
# 3.42515908608e+11
# 4.0665153536e+11
# 4.76609445888e+11
# 5.5261691904e+11
# 6.35364704256e+11
# 7.24975812608e+11
# 8.21188886528e+11
# 9.234546688e+11
# 1.03211604378e+12
# 1.14746064896e+12
# 1.26900083098e+12
# 1.39730839142e+12
# 1.53265242112e+12
# 1.67532350669e+12
# 1.82522989773e+12
# 1.98220342886e+12
# 2.14700038554e+12
# 2.31902753587e+12
# 2.49867717837e+12
# 2.68512736051e+12
# 2.87829340979e+12
# 3.07917592986e+12
# 3.28598185574e+12
# 3.50063794586e+12
# 3.72196455219e+12
# 3.95026576179e+12
# 4.18523329331e+12
# 4.4281060393e+12
# 4.67818197811e+12
# 4.93473287373e+12
# 5.19858867405e+12
# 5.47020131533e+12
# 5.74839010099e+12
# 6.03518612275e+12
# 6.32786046157e+12
# 6.62872470323e+12
# 6.93805305037e+12
# 7.25458983322e+12
# 7.57742593638e+12
# 7.90883939123e+12
# 8.2445294633e+12
# 8.59090609766e+12
# 8.94588524954e+12
# 9.30765655245e+12
# 9.67700591411e+12
# 1.00537844367e+13
# 1.04379019428e+13
# 1.08285520773e+13
# 1.12279399956e+13
# 1.16361883812e+13
# 1.20508414689e+13
# 1.2473405014e+13
# 1.29018951107e+13
# 1.33413973524e+13
# 1.37889432207e+13
# 1.42458381926e+13
# 1.47096736891e+13
# 1.51788841861e+13
# 1.56569677332e+13
# 1.61425695703e+13
# 1.66361500221e+13
# 1.71385615811e+13
# 1.76457766666e+13
# 1.81635593011e+13
# 1.86910643323e+13
# 1.92246301327e+13
# 1.97641413591e+13
# 2.03106780447e+13
# 2.08677613076e+13
# 2.14313037988e+13
# 2.20037717688e+13
# 2.25815853793e+13
# 2.31651787407e+13
# 2.37561561743e+13
# 2.43531608228e+13
# 2.49596613755e+13
# 2.55711552471e+13
# 2.61921240515e+13
# 2.68216387502e+13
# 2.74590135747e+13
# 2.81033006121e+13
# 2.87550598021e+13
# 2.94133746893e+13
# 3.00793295012e+13
# 3.07531737989e+13
# 3.14318834893e+13
# 3.21216409764e+13
# 3.28187636613e+13
# 3.35232137953e+13
# 3.42363545272e+13
# 3.49578649928e+13
# 3.56866106327e+13

# %%
plt.xlabel("iteration")
plt.ylabel("activation value")
plt.plot(curve)
plt.show()
plt.clf()
plt.xlabel("iteration")
plt.ylabel("grad")
plt.errorbar(range(len(grads_mean)), y=grads_mean, yerr=grads_std)
plt.show()

# %%
X_gen_ = X_gen
X_gen_ = X_gen_ + mean_value[np.newaxis, :, np.newaxis, np.newaxis]
#X_gen = X_gen[:, ::-1, :, :]
print(X_gen_.min(), X_gen_.max())
X_gen_ = X_gen_.transpose((0, 3, 2, 1))

print(X_gen_.shape)

mn = X_gen_.min(axis=(0, 1, 2))
mx = X_gen_.max(axis=(0, 1, 2))
X_gen_ = (X_gen_ - mn) / (mx - mn)
X_gen_ *= 255.
X_gen_ = np.round(X_gen_)
#print(X_gen_.min(axis=(1, 2))
plt.imshow(X_gen_[0])
# Out:
# (-4246.8879921874995, 4634.2155234375005)
# (1, 224, 224, 3)

# %%
cl_index = list(reversed(np.argsort(predict(X_gen.astype(np.float32))[0])))

# %%
print(X_gen.max())
# Out:
# 5244.6
